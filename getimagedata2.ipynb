# %% [markdown]
# <a href="https://colab.research.google.com/github/nobertomaciel/AI-Unifacs/blob/main/getimagedata2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (apenas se necessário) instalando a biblioteca Pillow (PIL) para captura dos pixels das imagens
# !pip install Pillow

# %%
from PIL import Image
import requests
from io import BytesIO
from google.colab import files

# %%
# url da imagem
url = "https://upload.wikimedia.org/wikipedia/commons/7/73/Lion_waiting_in_Namibia.jpg"

# baixa a imagem
response = requests.get(url)

# abre em binário
img = Image.open(BytesIO(response.content)).resize((28, 28))

# Usa getpixel() para acessar um pixel (ex: coordenada x=10, y=20)
x, y = 0, 0
pixel = img.getpixel((x, y))


print("Valores RGB do pixel em (",x,", ",y,"):", pixel)
print("R:", pixel[0])
print("G:", pixel[1])
print("B:", pixel[2])
# Out:
# Valores RGB do pixel em ( 0 ,  0 ): (165, 150, 111)
# R: 165
# G: 150
# B: 111

# %%
# pegando os pixels da imagem inteira
for x in range(img.width):
    for y in range(img.height):
        pixel = img.getpixel((x, y))
        print("Valores RGB do pixel em (",x,", ",y,"):", pixel)
# Out:
# Valores RGB do pixel em ( 0 ,  0 ): (165, 150, 111)
# Valores RGB do pixel em ( 0 ,  1 ): (186, 168, 126)
# Valores RGB do pixel em ( 0 ,  2 ): (193, 173, 133)
# Valores RGB do pixel em ( 0 ,  3 ): (196, 175, 134)
# Valores RGB do pixel em ( 0 ,  4 ): (200, 177, 134)
# Valores RGB do pixel em ( 0 ,  5 ): (199, 176, 132)
# Valores RGB do pixel em ( 0 ,  6 ): (196, 172, 128)
# Valores RGB do pixel em ( 0 ,  7 ): (198, 174, 128)
# Valores RGB do pixel em ( 0 ,  8 ): (200, 176, 127)
# Valores RGB do pixel em ( 0 ,  9 ): (192, 167, 120)
# Valores RGB do pixel em ( 0 ,  10 ): (183, 158, 112)
# Valores RGB do pixel em ( 0 ,  11 ): (177, 151, 105)
# Valores RGB do pixel em ( 0 ,  12 ): (180, 155, 107)
# Valores RGB do pixel em ( 0 ,  13 ): (185, 162, 115)
# Valores RGB do pixel em ( 0 ,  14 ): (180, 159, 115)
# Valores RGB do pixel em ( 0 ,  15 ): (158, 143, 108)
# Valores RGB do pixel em ( 0 ,  16 ): (133, 123, 96)
# Valores RGB do pixel em ( 0 ,  17 ): (114, 105, 84)
# ...
